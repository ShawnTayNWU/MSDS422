# %% [markdown]
# <a href="https://colab.research.google.com/github/ShawnTayNWU/MSDS422/blob/MSDS-422/Assignment_4_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import packages

# %%
import datetime
from packaging import version
from collections import Counter
import numpy as np
import pandas as pd
from packaging import version
from collections import Counter
import time

import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error as MSE
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import accuracy_score

import tensorflow as tf
from tensorflow import keras
import tensorflow_datasets as tfds
from tensorflow.keras import models, layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, BatchNormalization, Dropout, Flatten, Input, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import to_categorical

from timeit import default_timer as timer #import a timer
from datetime import datetime

# %%
# %matplotlib inline
np.set_printoptions(precision=3, suppress=True)

# %% [markdown]
# ### Verify TensorFlow Version and Keras Version

# %%
print("This notebook requires TensorFlow 2.0 or above")
print("TensorFlow version: ", tf.__version__)
assert version.parse(tf.__version__).release[0] >=2
# Out:
# This notebook requires TensorFlow 2.0 or above
# TensorFlow version:  2.7.0

# %%
print("Keras version: ", keras.__version__)
# Out:
# Keras version:  2.7.0

# %% [markdown]
# ### Functions for Research Assignment

# %%
def print_validation_report(y_test, predictions):
    print("Classification Report")
    print(classification_report(y_test, predictions))
    print('Accuracy Score: {}'.format(accuracy_score(y_test, predictions)))
    print('Root Mean Square Error: {}'.format(np.sqrt(MSE(y_test, predictions))))

# %%
def plot_confusion_matrix(y_true, y_pred):
    mtx = confusion_matrix(y_true, y_pred)
    fig, ax = plt.subplots(figsize=(8,8))
    sns.heatmap(mtx, annot=True, fmt='d', linewidths=.75,  cbar=False, ax=ax,cmap='Blues',linecolor='white')
    #  square=True,
    plt.ylabel('true label')
    plt.xlabel('predicted label')

# %% [markdown]
# ### Mount Google Drive to Colab Environment

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ###  TensorFlow Datasets Information<br>
# <div class="alert alert-block alert-info">
#     <b> ag_news_subset</b><br>
#     See https://www.tensorflow.org/datasets/catalog/ag_news_subset
#     </div>

# %%
#register  ag_news_subset so that tfds.load doesn't generate a checksum (mismatch) error
# !python -m tensorflow_datasets.scripts.download_and_prepare --register_checksums --datasets=stanford_online_products

# https://www.tensorflow.org/datasets/splits
# The full `train` and `test` splits, interleaved together.
ri = tfds.core.ReadInstruction('train') + tfds.core.ReadInstruction('test')
dataset_all, info = tfds.load('stanford_online_products', with_info=True,  split=ri)
# Out:
# Streaming output truncated to the last 5000 lines.
#
# Dl Completed...:   0% 0/1 [01:33<?, ? url/s]
# Dl Size...:  49% 1447/2940 [01:33<01:20, 18.47 MiB/s]
#
# Extraction completed...: 0 file [01:33, ? file/s]
# Dl Completed...:   0% 0/1 [01:33<?, ? url/s]
# Dl Size...:  49% 1448/2940 [01:33<01:07, 22.00 MiB/s]
#
# Dl Completed...:   0% 0/1 [01:33<?, ? url/s]
# Dl Size...:  49% 1449/2940 [01:33<01:07, 22.00 MiB/s]
#
# Dl Completed...:   0% 0/1 [01:33<?, ? url/s]
# Dl Size...:  49% 1450/2940 [01:33<01:07, 22.00 MiB/s]
#
# Dl Completed...:   0% 0/1 [01:33<?, ? url/s]
# Dl Size...:  49% 1451/2940 [01:33<01:07, 22.00 MiB/s]
#
# Dl Completed...:   0% 0/1 [01:33<?, ? url/s]
# Dl Size...:  49% 1452/2940 [01:33<01:07, 22.00 MiB/s]
#
# Extraction completed...: 0 file [01:33, ? file/s]
# Dl Completed...:   0% 0/1 [01:33<?, ? url/s]
# Dl Size...:  49% 1453/2940 [01:33<00:59, 25.07 MiB/s]
#
# Dl Completed...:   0% 0/1 [01:33<?, ? url/s]
# Dl Size...:  49% 1454/2940 [01:33<00:59, 25.07 MiB/s]
#
# Dl Completed...:   0% 0/1 [01:33<?, ? url/s]
# Dl Size...:  49% 1455/2940 [01:33<00:59, 25.07 MiB/s]
#
# Dl Completed...:   0% 0/1 [01:33<?, ? url/s]
# Dl Size...:  50% 1456/2940 [01:33<00:59, 25.07 MiB/s]
#
# Extraction completed...: 0 file [01:33, ? file/s]
# Dl Completed...:   0% 0/1 [01:33<?, ? url/s]
# Dl Size...:  50% 1457/2940 [01:33<00:57, 25.85 MiB/s]
#
# Dl Completed...:   0% 0/1 [01:33<?, ? url/s]
# Dl Size...:  50% 1458/2940 [01:33<00:57, 25.85 MiB/s]
#
# Dl Completed...:   0% 0/1 [01:33<?, ? url/s]
# Dl Size...:  50% 1459/2940 [01:33<00:57, 25.85 MiB/s]
#
# Dl Completed...:   0% 0/1 [01:33<?, ? url/s]
# Dl Size...:  50% 1460/2940 [01:33<00:57, 25.85 MiB/s]
#
# Dl Completed...:   0% 0/1 [01:33<?, ? url/s]
# Dl Size...:  50% 1461/2940 [01:33<00:57, 25.85 MiB/s]
#
# Extraction completed...: 0 file [01:33, ? file/s]
# Dl Completed...:   0% 0/1 [01:33<?, ? url/s]
# Dl Size...:  50% 1462/2940 [01:33<00:52, 28.38 MiB/s]
#
# Dl Completed...:   0% 0/1 [01:33<?, ? url/s]
# Dl Size...:  50% 1463/2940 [01:33<00:52, 28.38 MiB/s]
#
# Dl Completed...:   0% 0/1 [01:33<?, ? url/s]
# Dl Size...:  50% 1464/2940 [01:33<00:52, 28.38 MiB/s]
#
# Dl Completed...:   0% 0/1 [01:33<?, ? url/s]
# Dl Size...:  50% 1465/2940 [01:33<00:51, 28.38 MiB/s]
#
# Extraction completed...: 0 file [01:33, ? file/s]
# Dl Completed...:   0% 0/1 [01:33<?, ? url/s]
# Dl Size...:  50% 1466/2940 [01:33<00:48, 30.28 MiB/s]
#
# Dl Completed...:   0% 0/1 [01:33<?, ? url/s]
# Dl Size...:  50% 1467/2940 [01:33<00:48, 30.28 MiB/s]
#
# Dl Completed...:   0% 0/1 [01:33<?, ? url/s]
# Dl Size...:  50% 1468/2940 [01:33<00:48, 30.28 MiB/s]
#
# Dl Completed...:   0% 0/1 [01:33<?, ? url/s]
# Dl Size...:  50% 1469/2940 [01:33<00:48, 30.28 MiB/s]
#
# Extraction completed...: 0 file [01:33, ? file/s]
# Dl Completed...:   0% 0/1 [01:33<?, ? url/s]
# Dl Size...:  50% 1470/2940 [01:33<00:55, 26.66 MiB/s]
#
# Dl Completed...:   0% 0/1 [01:33<?, ? url/s]
# Dl Size...:  50% 1471/2940 [01:33<00:55, 26.66 MiB/s]
#
# Dl Completed...:   0% 0/1 [01:34<?, ? url/s]
# Dl Size...:  50% 1472/2940 [01:34<00:55, 26.66 MiB/s]
#
# Extraction completed...: 0 file [01:34, ? file/s]
# Dl Completed...:   0% 0/1 [01:34<?, ? url/s]
# Dl Size...:  50% 1473/2940 [01:34<00:58, 25.20 MiB/s]
#
# Dl Completed...:   0% 0/1 [01:34<?, ? url/s]
# Dl Size...:  50% 1474/2940 [01:34<00:58, 25.20 MiB/s]
#
# Dl Completed...:   0% 0/1 [01:34<?, ? url/s]
# Dl Size...:  50% 1475/2940 [01:34<00:58, 25.20 MiB/s]
#
# Extraction completed...: 0 file [01:34, ? file/s]
# Dl Completed...:   0% 0/1 [01:34<?, ? url/s]
# Dl Size...:  50% 1476/2940 [01:34<01:00, 24.35 MiB/s]
#
# Dl Completed...:   0% 0/1 [01:34<?, ? url/s]
# Dl Size...:  50% 1477/2940 [01:34<01:00, 24.35 MiB/s]
#
# Dl Completed...:   0% 0/1 [01:34<?, ? url/s]
# Dl Size...:  50% 1478/2940 [01:34<01:00, 24.35 MiB/s]
#
# Dl Completed...:   0% 0/1 [01:34<?, ? url/s]
# Dl Size...:  50% 1479/2940 [01:34<00:59, 24.35 MiB/s]
#
# Extraction completed...: 0 file [01:34, ? file/s]
# Dl Completed...:   0% 0/1 [01:34<?, ? url/s]
# Dl Size...:  50% 1480/2940 [01:34<00:57, 25.22 MiB/s]
#
# Dl Completed...:   0% 0/1 [01:34<?, ? url/s]
# Dl Size...:  50% 1481/2940 [01:34<00:57, 25.22 MiB/s]
#
# Dl Completed...:   0% 0/1 [01:34<?, ? url/s]
# Dl Size...:  50% 1482/2940 [01:34<00:57, 25.22 MiB/s]
#
# Extraction completed...: 0 file [01:34, ? file/s]
# Dl Completed...:   0% 0/1 [01:34<?, ? url/s]
# Dl Size...:  50% 
MiB/s]
#
# Dl Completed...:   0% 0/1 [02:30<?, ? url/s]
# Dl Size...:  99% 2920/2940 [02:30<00:00, 22.35 MiB/s]
#
# Extraction completed...: 0 file [02:30, ? file/s]
# Dl Completed...:   0% 0/1 [02:30<?, ? url/s]
# Dl Size...:  99% 2921/2940 [02:30<00:00, 25.47 MiB/s]
#
# Dl Completed...:   0% 0/1 [02:30<?, ? url/s]
# Dl Size...:  99% 2922/2940 [02:30<00:00, 25.47 MiB/s]
#
# Dl Completed...:   0% 0/1 [02:30<?, ? url/s]
# Dl Size...:  99% 2923/2940 [02:30<00:00, 25.47 MiB/s]
#
# Dl Completed...:   0% 0/1 [02:30<?, ? url/s]
# Dl Size...:  99% 2924/2940 [02:30<00:00, 25.47 MiB/s]
#
# Dl Completed...:   0% 0/1 [02:30<?, ? url/s]
# Dl Size...:  99% 2925/2940 [02:30<00:00, 25.47 MiB/s]
#
# Extraction completed...: 0 file [02:30, ? file/s]
# Dl Completed...:   0% 0/1 [02:30<?, ? url/s]
# Dl Size...: 100% 2926/2940 [02:30<00:00, 27.17 MiB/s]
#
# Dl Completed...:   0% 0/1 [02:30<?, ? url/s]
# Dl Size...: 100% 2927/2940 [02:30<00:00, 27.17 MiB/s]
#
# Dl Completed...:   0% 0/1 [02:30<?, ? url/s]
# Dl Size...: 100% 2928/2940 [02:30<00:00, 27.17 MiB/s]
#
# Dl Completed...:   0% 0/1 [02:30<?, ? url/s]
# Dl Size...: 100% 2929/2940 [02:30<00:00, 27.17 MiB/s]
#
# Dl Completed...:   0% 0/1 [02:31<?, ? url/s]
# Dl Size...: 100% 2930/2940 [02:31<00:00, 27.17 MiB/s]
#
# Extraction completed...: 0 file [02:31, ? file/s]
# Dl Completed...:   0% 0/1 [02:31<?, ? url/s]
# Dl Size...: 100% 2931/2940 [02:31<00:00, 29.14 MiB/s]
#
# Dl Completed...:   0% 0/1 [02:31<?, ? url/s]
# Dl Size...: 100% 2932/2940 [02:31<00:00, 29.14 MiB/s]
#
# Dl Completed...:   0% 0/1 [02:31<?, ? url/s]
# Dl Size...: 100% 2933/2940 [02:31<00:00, 29.14 MiB/s]
#
# Dl Completed...:   0% 0/1 [02:31<?, ? url/s]
# Dl Size...: 100% 2934/2940 [02:31<00:00, 29.14 MiB/s]
#
# Extraction completed...: 0 file [02:31, ? file/s]
# Dl Completed...:   0% 0/1 [02:31<?, ? url/s]
# Dl Size...: 100% 2935/2940 [02:31<00:00, 28.01 MiB/s]
#
# Dl Completed...:   0% 0/1 [02:31<?, ? url/s]
# Dl Size...: 100% 2936/2940 [02:31<00:00, 28.01 MiB/s]
#
# Dl Completed...:   0% 0/1 [02:31<?, ? url/s]
# Dl Size...: 100% 2937/2940 [02:31<00:00, 28.01 MiB/s]
#
# Dl Completed...:   0% 0/1 [02:31<?, ? url/s]
# Dl Size...: 100% 2938/2940 [02:31<00:00, 28.01 MiB/s]
#
# Dl Completed...:   0% 0/1 [02:31<?, ? url/s]
# Dl Size...: 100% 2939/2940 [02:31<00:00, 28.01 MiB/s]
#
# Extraction completed...: 0 file [02:31, ? file/s]
# Dl Completed...:   0% 0/1 [02:31<?, ? url/s]
# Dl Size...: 100% 2940/2940 [02:31<00:00, 30.06 MiB/s]
#
# Dl Completed...: 100% 1/1 [02:31<00:00, 151.38s/ url]
# Dl Size...: 100% 2940/2940 [02:31<00:00, 30.06 MiB/s]
#
# Dl Completed...: 100% 1/1 [02:31<00:00, 151.38s/ url]
# Dl Size...: 100% 2940/2940 [02:31<00:00, 30.06 MiB/s]
#
# Extraction completed...:   0% 0/1 [02:31<?, ? file/s]
# Dl Size...: 100% 2940/2940 [02:50<00:00, 30.06 MiB/s]
#
# Dl Completed...: 100% 1/1 [03:31<00:00, 151.38s/ url]
# Dl Size...: 100% 2940/2940 [03:31<00:00, 30.06 MiB/s]
#
# Extraction completed...: 100% 1/1 [03:31<00:00, 211.57s/ file]
# Extraction completed...: 100% 1/1 [03:31<00:00, 211.62s/ file]
#
# Dl Size...: 100% 2940/2940 [03:31<00:00, 13.89 MiB/s]
#
# Dl Completed...: 100% 1/1 [03:31<00:00, 211.62s/ url]
# I1117 14:48:23.944638 139906487207808 dataset_builder.py:970] Generating split train
# Shuffling and writing examples to /root/tensorflow_datasets/stanford_online_products/1.0.0.incompleteN9U0WN/stanford_online_products-train.tfrecord
#  99% 58861/59551 [00:15<00:00, 882.93 examples/s] I1117 14:49:21.644726 139906487207808 tfrecords_writer.py:226] Done writing /root/tensorflow_datasets/stanford_online_products/1.0.0.incompleteN9U0WN/stanford_online_products-train.tfrecord. Shard lengths: [3722, 3722, 3722, 3722, 3722, 3722, 3722, 3722, 3721, 3722, 3722, 3722, 3722, 3722, 3722, 3722]
# I1117 14:49:21.647853 139906487207808 dataset_builder.py:970] Generating split test
# Shuffling and writing examples to /root/tensorflow_datasets/stanford_online_products/1.0.0.incompleteN9U0WN/stanford_online_products-test.tfrecord
# 100% 60396/60502 [00:12<00:00, 4389.88 examples/s]I1117 14:51:04.917013 139906487207808 tfrecords_writer.py:226] Done writing /root/tensorflow_datasets/stanford_online_products/1.0.0.incompleteN9U0WN/stanford_online_products-test.tfrecord. Shard lengths: [3781, 3782, 3781, 3782, 3781, 3781, 3782, 3781, 3781, 3782, 3781, 3781, 3782, 3781, 3782, 3781]
# I1117 14:51:04.921982 139906487207808 dataset_builder.py:412] Skipping computing stats for mode ComputeStatsMode.SKIP.
# Dataset stanford_online_products downloaded and prepared to /root/tensorflow_datasets/stanford_online_products/1.0.0. Subsequent calls will reuse this data.
# name: "stanford_online_products"
# description: "Stanford Online Products Dataset"
# citation: "@inproceedings{song2016deep,\n author    = {Song, Hyun Oh and Xiang, Yu and Jegelka, Stefanie and Savarese, Silvio},\n title     = {Deep Metric Learning via Lifted Structured Feature Embedding},\n booktitle = {IEEE Conference on Computer Vision and Pattern Recognition (CVPR)},\n year      = {2016}\n}"
# size_in_bytes: 3083860082
# location {
#   urls: "http://cvgl.stanford.edu/projects/lifted_struct/"
# }
# schema {
#   feature {
#     name: "class_id"
#     type: INT
#   }
#   feature {
#     name: "image"
#     type: INT
#     shape {
#       dim {
#         size: -1
#       }
#       dim {
#         size: -1
#       }
#       dim {
#         size: 3
#       }
#     }
#   }
#   feature {
#     name: "super_class_id"
#     type: INT
#   }
#   feature {
#     name: "super_class_id/num"
#     type: INT
#   }
# }
# splits {
#   name: "test"
#   shard_lengths: 3781
#   shard_lengths: 3782
#   shard_lengths: 3781
#   shard_lengths: 3782
#   shard_lengths: 3781
#   shard_lengths: 3781
#   shard_lengths: 3782
#   shard_lengths: 3781
#   shard_lengths: 3781
#   shard_lengths: 3782
#   shard_lengths: 3781
#   shard_lengths: 3781
#   shard_lengths: 3782
#   shard_lengths: 3781
#   shard_lengths: 3782
#   shard_lengths: 3781
#   num_bytes: 1448062031
# }
# splits {
#   name: "train"
#   shard_lengths: 3722
#   shard_lengths: 3722
#   shard_lengths: 3722
#   shard_lengths: 3722
#   shard_lengths: 3722
#   shard_lengths: 3722
#   shard_lengths: 3722
#   shard_lengths: 3722
#   shard_lengths: 3721
#   shard_lengths: 3722
#   shard_lengths: 3722
#   shard_lengths: 3722
#   shard_lengths: 3722
#   shard_lengths: 3722
#   shard_lengths: 3722
#   shard_lengths: 3722
#   num_bytes: 1653923002
# }
# version: "1.0.0"
# download_size: 3083860082

# %%
print(info)
# Out:
# tfds.core.DatasetInfo(
#     name='stanford_online_products',
#     version=1.0.0,
#     description='Stanford Online Products Dataset',
#     homepage='http://cvgl.stanford.edu/projects/lifted_struct/',
#     features=FeaturesDict({
#         'class_id': ClassLabel(shape=(), dtype=tf.int64, num_classes=22634),
#         'image': Image(shape=(None, None, 3), dtype=tf.uint8),
#         'super_class_id': ClassLabel(shape=(), dtype=tf.int64, num_classes=12),
#         'super_class_id/num': ClassLabel(shape=(), dtype=tf.int64, num_classes=12),
#     }),
#     total_num_examples=120053,
#     splits={
#         'test': 60502,
#         'train': 59551,
#     },
#     supervised_keys=None,
#     citation="""@inproceedings{song2016deep,
#      author    = {Song, Hyun Oh and Xiang, Yu and Jegelka, Stefanie and Savarese, Silvio},
#      title     = {Deep Metric Learning via Lifted Structured Feature Embedding},
#      booktitle = {IEEE Conference on Computer Vision and Pattern Recognition (CVPR)},
#      year      = {2016}
#     }""",
#     redistribution_info=,
# )

# %%
tfds.as_dataframe(dataset_all.take(10),info)
# Out:
#    class_id  ... super_class_id/num
# 0      2773  ...                  3
# 1       243  ...                  0
# 2      8848  ...                  9
# 3      2942  ...                  3
# 4      4740  ...                  5
# 5     10298  ...                 10
# 6      9384  ...                 10
# 7      9008  ...                  9
# 8      4592  ...                  5
# 9       214  ...                  0
#
# [10 rows x 4 columns]

# %% [markdown]
# ### Review Labels (Categories)

# %%
print(f'There are {info.features["super_class_id"].num_classes} classes in the dataset.')
print(f'The class names are {info.features["super_class_id"].names}')
# Out:
# There are 12 classes in the dataset.
# The class names are ['bicycle', 'cabinet', 'chair', 'coffee_maker', 'fan', 'kettle', 'lamp', 'mug', 'sofa', 'stapler', 'table', 'toaster']

# %%
# classes dictionary
categories =dict(enumerate(info.features["super_class_id"].names))
categories
# Out:
# {0: 'bicycle',
#  1: 'cabinet',
#  2: 'chair',
#  3: 'coffee_maker',
#  4: 'fan',
#  5: 'kettle',
#  6: 'lamp',
#  7: 'mug',
#  8: 'sofa',
#  9: 'stapler',
#  10: 'table',
#  11: 'toaster'}

# %%
train_categories = [categories[label] for label in dataset_all.map(lambda text, label: label).as_numpy_iterator()]
Counter(train_categories).most_common()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-eac225f63a2e> in <module>()
# ----> 1 train_categories = [categories[label] for label in dataset_all.map(lambda text, label: label).as_numpy_iterator()]
#       2 Counter(train_categories).most_common()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py in map(self, map_func, num_parallel_calls, deterministic, name)
#    2002         warnings.warn("The `deterministic` argument has no effect unless the "
#    2003                       "`num_parallel_calls` argument is specified.")
# -> 2004       return MapDataset(self, map_func, preserve_cardinality=True, name=name)
#    2005     else:
#    2006       return ParallelMapDataset(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, input_dataset, map_func, use_inter_op_parallelism, preserve_cardinality, use_legacy_function, name)
#    5457         self._transformation_name(),
#    5458         dataset=input_dataset,
# -> 5459         use_legacy_function=use_legacy_function)
#    5460     self._metadata = dataset_metadata_pb2.Metadata()
#    5461     if name:
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#    4531         fn_factory = trace_tf_function(defun_kwargs)
#    4532
# -> 4533     self._function = fn_factory()
#    4534     # There is no graph to add in eager mode.
#    4535     add_to_graph &= not context.executing_eagerly()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in get_concrete_function(self, *args, **kwargs)
#    3243     """
#    3244     graph_function = self._get_concrete_function_garbage_collected(
# -> 3245         *args, **kwargs)
#    3246     graph_function._garbage_collector.release()  # pylint: disable=protected-access
#    3247     return graph_function
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#    3208       args, kwargs = None, None
#    3209     with self._lock:
# -> 3210       graph_function, _ = self._maybe_define_function(args, kwargs)
#    3211       seen_names = set()
#    3212       captured = object_identity.ObjectIdentitySet(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3555
#    3556           self._function_cache.missed.add(call_context_key)
# -> 3557           graph_function = self._create_graph_function(args, kwargs)
#    3558           self._function_cache.primary[cache_key] = graph_function
#    3559
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3400             arg_names=arg_names,
#    3401             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 3402             capture_by_value=self._capture_by_value),
#    3403         self._function_attributes,
#    3404         function_spec=self.function_spec,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1141         _, original_func = tf_decorator.unwrap(python_func)
#    1142
# -> 1143       func_outputs = python_func(*func_args, **func_kwargs)
#    1144
#    1145       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py in wrapped_fn(*args)
#    4508           attributes=defun_kwargs)
#    4509       def wrapped_fn(*args):  # pylint: disable=missing-docstring
# -> 4510         ret = wrapper_helper(*args)
#    4511         ret = structure.to_tensor_list(self._output_structure, ret)
#    4512         return [ops.convert_to_tensor(t) for t in ret]
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py in wrapper_helper(*args)
#    4438       if not _should_unpack(nested_args):
#    4439         nested_args = (nested_args,)
# -> 4440       ret = autograph.tf_convert(self._func, ag_ctx)(*nested_args)
#    4441       if _should_pack(ret):
#    4442         ret = tuple(ret)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     697       except Exception as e:  # pylint:disable=broad-except
#     698         if hasattr(e, 'ag_error_metadata'):
# --> 699           raise e.ag_error_metadata.to_exception(e)
#     700         else:
#     701           raise
#
# TypeError: in user code:
#
#
#     TypeError: <lambda>() missing 1 required positional argument: 'label'

# %%
 
class_names = dataset_all.super_class_id
plt.figure(figsize=(10, 10))
for images, labels in dataset_all.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-7d3f22079535> in <module>()
#       1
# ----> 2 class_names = dataset_all.super_class_id
#       3 plt.figure(figsize=(10, 10))
#       4 for images, labels in dataset_all.take(1):
#       5    for i in range(9):
#
# AttributeError: 'PrefetchDataset' object has no attribute 'super_class_id'
